# %%
# importing libraries
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd


import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %% [markdown]
# ### Scrape and transform the data about Toronto neighbrhood into a dataframe ###

# %%
# specify the url
post_codes = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
# query the website and return the html to the variable ‘page’
page = requests.get(post_codes, timeout=5)

# %%
# parse the html using beautiful soup and store in variable `soup`
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# ### Creating the dataframe by droping the cells with "not assigned" borough and combining borough listed twice ###

# %%
code_table = soup.find('table')
code_rows = code_table.findAll('tr')
columns=['Postcode', 'Borough', 'Neighbourhood']
df_codes = pd.DataFrame(columns=columns)
for idx, val in enumerate(code_rows):
    code_cells = val.findAll('td')
    df_list = []
    for idx, val in enumerate(code_cells):
        df_list.append(val.text.rstrip())
    if(int(len(df_list)) > 0):
        if(df_list[1] != "Not assigned"):
            if(df_list[2] == "Not assigned"):
                df_list[2] = df_list[1]

            df_dic={columns[0]: df_list[0], columns[1]: df_list[1], columns[2]: df_list[2]}
            df_codes = df_codes.append(df_dic, ignore_index=True)

df_codes = df_codes.groupby('Postcode', as_index=False).agg(lambda x: ', '.join(set(x.dropna())))

# %% [markdown]
# ### shape of our dataframe ###

# %%
df_codes.shape
# Out:
# (103, 3)

# %%
df_codes
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                       Malvern, Rouge
# 1               Rouge Hill, Highland Creek, Port Union
# 2                    West Hill, Morningside, Guildwood
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6          Kennedy Park, East Birchmount Park, Ionview
# 7                      Golden Mile, Clairlea, Oakridge
# 8      Cliffside, Cliffcrest, Scarborough Village West
# 9                          Birch Cliff, Cliffside West
# 10   Wexford Heights, Scarborough Town Centre, Dors...
# 11                                   Wexford, Maryvale
# 12                                           Agincourt
# 13             Clarks Corners, Sullivan, Tam O'Shanter
# 14   Agincourt North, L'Amoreaux East, Milliken, St...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                        Henry Farm, Fairview, Oriole
# 19                                     Bayview Village
# 20                            York Mills, Silver Hills
# 21                             Willowdale, Newtonbrook
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                    Don Mills South, Flemingdon Park
# 28     Downsview North, Bathurst Manor, Wilson Heights
# 29                     York University, Northwood Park
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                        Dufferin, Dovercourt Village
# 77                            Little Portugal, Trinity
# 78        Parkdale Village, Exhibition Place, Brockton
# 79                  Downsview, North Park, Upwood Park
# 80      Silverthorn, Keelesdale, Del Ray, Mount Dennis
# 81                       The Junction North, Runnymede
# 82                       The Junction South, High Park
# 83                              Parkdale, Roncesvalles
# 84                                  Swansea, Runnymede
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88        Mimico South, Humber Bay Shores, New Toronto
# 89                              Long Branch, Alderwood
# 90       Montgomery Road, The Kingsway, Old Mill North
# 91   Sunnylea, Kingsway Park South East, Royal York...
# 92   Kingsway Park South West, Mimico NW, The Queen...
# 93                                    Islington Avenue
# 94   Islington, Princess Gardens, West Deane Park, ...
# 95   Old Burnhamthorpe, Bloordale Gardens, Markland...
# 96                                       Humber Summit
# 97                                    Humberlea, Emery
# 98                                              Weston
# 99                                           Westmount
# 100  Richview Gardens, St. Phillips, Kingsview Vill...
# 101  Humbergate, Mount Olive, Thistletown, South St...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %%
# !wget -O Geospatial_data.csv https://cocl.us/Geospatial_data
# Out:
# --2019-08-31 05:24:35--  https://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.48.113.201
# Connecting to cocl.us (cocl.us)|169.48.113.201|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-08-31 05:24:36--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 185.235.236.197
# Connecting to ibm.box.com (ibm.box.com)|185.235.236.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-08-31 05:24:36--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-08-31 05:24:36--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.26.211, 107.152.27.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.26.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!ZShApPAUxPUQ7jSNyU3_AsB-Z-i3uqKnRshAWoGN2YtzpKj8E2jubfg44hH_kejGC4Qo9MOvHKglAjvOXXjX0fT5MA9F2aviOiXhRYYK_-Yn7IWXDVbqkoujNGY50Y5aF7Nn1G8RzK3k1prM2U_8zS3K-RThHBMvLvsfHL53qS-nx83eNxLCpGN7YYyI_ya7VLCpSlLTkynz4sDsfM4nioW6VyeQSycBTkHViz7YMs7G_6H-YK0x8Iz8QF2uCUMlX962E_P4TaI6x5ktFaQTH4IettAP2YwJJYCgmnJXhrcLWluK8e_DgekU6degui-3MfxkK-os79DrhXdSgH42Jv5BWfJYLUtCRNpk_SnpWO2m7uHYIFdQioi22LUHhksBec
EnAS7HEsx01oai_TKwIY2zwdBAV0jXYFfgJd3Xl9PvvMu5_3Ml3WSugNHEoSXG-oMgPcqIA278j1tS3jopGTROLOZisAhNDC-duyd_vZXZ-umlRk1d3scoyhjNSpHoJMzpgZryJLnJfC01G3tDTFi1buKKce31e3Vt6a-ayybrf_iEEm-Dw1UQwBnE0NjUyZFZQYzT4gB-nksLVZilFqWupReG87RBn58nc96E4yPq1ROLw9p01jBygx9pfBT2mK1LEgiH-ATUfMoCAWhn_f_0YHu1LvPA4FeiSSFeAPgm7ji5DewaWQB9jlF0s-ZZt4j7E-gALe9r9x57Oe8fhAFOYU45HaHfG1pR4pTnQSLu5q1kq-uLtT_TW77QljUmf6qNEJWmWRnj63cGf1bHyiaWkJnRn04re4GFkKagxdBQ8nwIspOdUFO6vSl81Q_HNWiwbouNfM14I2BdyF0tc8T-9WdPbws0aoxyPGKdQmKPgLbtbPptlE4PfLBwKI484eUypwe8g0AlXPRRE9A8YuRt4xZQ6VTtrmPzYkJi3cQZedCrEzW0NevsLzEgg7zeEDd-y86ideVSvhxiMz1AjtC7BMiyMsazvWvNEmliOS9tQ1UlNH_CkX2nrWCdRgE4Rh-CS8YbWu3sXwbveqmIakStcZKU0rLiZO0gERDBU-s9a-hrYqVNi0gQFPRW4h5djtmD_kKZUlzgOVXOwzBUtR-1Ndx9gTYebg../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.24.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.24.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_data.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2019-08-31 05:24:38 (421 MB/s) - ‘Geospatial_data.csv’ saved [2891/2891]

# %% [markdown]
# # Using the csv file to create the dataframe with the geographical coordinates #

# %%
df_geo = pd.read_csv("Geospatial_data.csv")
df_codes = df_codes.join(df_geo)

# %%
df_codes
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood Postal Code   Latitude  \
# 0                                       Malvern, Rouge         M1B  43.806686
# 1               Rouge Hill, Highland Creek, Port Union         M1C  43.784535
# 2                    West Hill, Morningside, Guildwood         M1E  43.763573
# 3                                               Woburn         M1G  43.770992
# 4                                            Cedarbrae         M1H  43.773136
# 5                                  Scarborough Village         M1J  43.744734
# 6          Kennedy Park, East Birchmount Park, Ionview         M1K  43.727929
# 7                      Golden Mile, Clairlea, Oakridge         M1L  43.711112
# 8      Cliffside, Cliffcrest, Scarborough Village West         M1M  43.716316
# 9                          Birch Cliff, Cliffside West         M1N  43.692657
# 10   Wexford Heights, Scarborough Town Centre, Dors...         M1P  43.757410
# 11                                   Wexford, Maryvale         M1R  43.750072
# 12                                           Agincourt         M1S  43.794200
# 13             Clarks Corners, Sullivan, Tam O'Shanter         M1T  43.781638
# 14   Agincourt North, L'Amoreaux East, Milliken, St...         M1V  43.815252
# 15                                     L'Amoreaux West         M1W  43.799525
# 16                                         Upper Rouge         M1X  43.836125
# 17                                   Hillcrest Village         M2H  43.803762
# 18                        Henry Farm, Fairview, Oriole         M2J  43.778517
# 19                                     Bayview Village         M2K  43.786947
# 20                            York Mills, Silver Hills         M2L  43.757490
# 21                             Willowdale, Newtonbrook         M2M  43.789053
# 22                                    Willowdale South         M2N  43.770120
# 23                                     York Mills West         M2P  43.752758
# 24                                     Willowdale West         M2R  43.782736
# 25                                           Parkwoods         M3A  43.753259
# 26                                     Don Mills North         M3B  43.745906
# 27                    Don Mills South, Flemingdon Park         M3C  43.725900
# 28     Downsview North, Bathurst Manor, Wilson Heights         M3H  43.754328
# 29                     York University, Northwood Park         M3J  43.767980
# ..                                                 ...         ...        ...
# 73                                  Humewood-Cedarvale         M6C  43.693781
# 74                                 Caledonia-Fairbanks         M6E  43.689026
# 75                                            Christie         M6G  43.669542
# 76                        Dufferin, Dovercourt Village         M6H  43.669005
# 77                            Little Portugal, Trinity         M6J  43.647927
# 78        Parkdale Village, Exhibition Place, Brockton         M6K  43.636847
# 79                  Downsview, North Park, Upwood Park         M6L  43.713756
# 80      Silverthorn, Keelesdale, Del Ray, Mount Dennis         M6M  43.691116
# 81                       The Junction North, Runnymede         M6N  43.673185
# 82                       The Junction South, High Park         M6P  43.661608
# 83                              Parkdale, Roncesvalles         M6R  43.648960
# 84                                  Swansea, Runnymede         M6S  43.651571
# 85                                        Queen's Park         M7A  43.662301
# 86               Canada Post Gateway Processing Centre         M7R  43.636966
# 87   Business Reply Mail Processing Centre 969 Eastern         M7Y  43.662744
# 88        Mimico South, Humber Bay Shores, New Toronto         M8V  43.605647
# 89                              Long Branch, Alderwood         M8W  43.602414
# 90       Montgomery Road, The Kingsway, Old Mill North         M8X  43.653654
# 91   Sunnylea, Kingsway Park South East, Royal York...         M8Y  43.636258
# 92   Kingsway Park South West, Mimico NW, The Queen...         M8Z  43.628841
# 93                                    Islington Avenue         M9A  43.667856
# 94   Islington, Princess Gardens, West Deane Park, ...         M9B  43.650943
# 95   Old Burnhamthorpe, Bloordale Gardens, Markland...         M9C  43.643515
# 96                                       Humber Summit         M9L  43.756303
# 97                                    Humberlea, Emery         M9M  43.724766
# 98                                              Weston         M9N  43.706876
# 99                                           Westmount         M9P  43.696319
# 100  Richview Gardens, St. Phillips, Kingsview Vill...         M9R  43.688905
# 101  Humbergate, Mount Olive, Thistletown, South St...         M9V  43.739416
# 102                                          Northwest         M9W  43.706748
#
#      Longitude
# 0   -79.194353
# 1   -79.160497
# 2   -79.188711
# 3   -79.216917
# 4   -79.239476
# 5   -79.239476
# 6   -79.262029
# 7   -79.284577
# 8   -79.239476
# 9   -79.264848
# 10  -79.273304
# 11  -79.295849
# 12  -79.262029
# 13  -79.304302
# 14  -79.284577
# 15  -79.318389
# 16  -79.205636
# 17  -79.363452
# 18  -79.346556
# 19  -79.385975
# 20  -79.374714
# 21  -79.408493
# 22  -79.408493
# 23  -79.400049
# 24  -79.442259
# 25  -79.329656
# 26  -79.352188
# 27  -79.340923
# 28  -79.442259
# 29  -79.487262
# ..         ...
# 73  -79.428191
# 74  -79.453512
# 75  -79.422564
# 76  -79.442259
# 77  -79.419750
# 78  -79.428191
# 79  -79.490074
# 80  -79.476013
# 81  -79.487262
# 82  -79.464763
# 83  -79.456325
# 84  -79.484450
# 85  -79.389494
# 86  -79.615819
# 87  -79.321558
# 88  -79.501321
# 89  -79.543484
# 90  -79.506944
# 91  -79.498509
# 92  -79.520999
# 93  -79.532242
# 94  -79.554724
# 95  -79.577201
# 96  -79.565963
# 97  -79.532242
# 98  -79.518188
# 99  -79.532242
# 100 -79.554724
# 101 -79.588437
# 102 -79.594054
#
# [103 rows x 6 columns]

# %% [markdown]
# # Exploring and clustering the neighborhoods in Toronto ###

# %%
# !pip install geopy
# !conda install -c conda-forge folium=0.5.0 --yes 

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # map rendering library
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.18.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geopy) (1.49)
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# ### Checking the geographical coordinate of Toronto ###

# %%
address = 'Toronto, Canada'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
folium.TileLayer('openstreetmap').add_to(map_toronto)
# add markers to map
for lat, lng, label in zip(df_codes['Latitude'], df_codes['Longitude'], df_codes['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
